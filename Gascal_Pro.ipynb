# %% [markdown]
# <a href="https://colab.research.google.com/github/AadarshAK/Gascal-Pro/blob/main/Gascal_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing all modules

# %%
import pandas as pd
import csv
from datetime import date

# %% [markdown]
# Setting Date for storing in CSV file

# %%
today = date.today()
d = today.strftime("%d/%m/%Y")

# %% [markdown]
# Inputing all arguments

# %%
previousReading = int(input("Enter Previous Reading : "))
currentReading = int(input("Enter Current Reading : "))
rplpg = float(input("Enter Rate Per Unit Of LPG : "))
# Out:
# Enter Previous Reading : 654
# Enter Current Reading : 845
# Enter Rate Per Unit Of LPG : 2

# %% [markdown]
# Calculating Units Consumed and Total Amount

# %%
ta = (currentReading - previousReading) * rplpg
uc = (currentReading - previousReading)

# %% [markdown]
# Storing values in Dictionaries and Lists

# %%
values = {'Date':d, 'Previous Reading':previousReading, 'Current Reading':currentReading, 'Rate/Unit of LPG':rplpg, 'Units Consumed':uc, 'Total Amount':ta}
data = pd.DataFrame(
    {
        'Date':[d],
        'Previous Reading':[previousReading],
        'Current Reading':[currentReading],
        'Rate/Unit of LPG':[rplpg],
        'Units Consumed':[uc],
        'Total Amount':[ta]
    })

# %% [markdown]
# Importing CSV File

# %%
from google.colab import files
file1 = files.upload()
# Out:
#      <input type="file" id="files-5812a9e2-14d1-45b7-95e0-81a9381b6dcf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5812a9e2-14d1-45b7-95e0-81a9381b6dcf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# Writing to CSV file

# %%
data.to_csv('/Gascal.csv', mode='a',index=False, header=False)
